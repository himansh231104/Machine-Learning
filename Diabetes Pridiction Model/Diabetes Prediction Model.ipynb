# %% [markdown]
# <h1 style="color: orange; text-align: center;">Diabetes Prediction Model</h1>

# %% [markdown]
# <img src="diabetes-image.jpg" alt="Diabetes Image" style="height: 300px; width: 600px; margin-left: 220px"/>

# %% [markdown]
# ## Importing the Dependencies

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn import svm
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Data Collection and Analysis

# %%
# Loading the diabetes dataset to a pandas dataframe
diabetes_dataset = pd.read_csv('diabetes.csv')
diabetes_dataset.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
diabetes_dataset.shape
# Out:
# (768, 9)

# %%
diabetes_dataset.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
# Check the number of Outcome in each case
diabetes_dataset['Outcome'].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %% [raw]
# 0 ---> Non-Diabetic
# 1 ---> Diabetic

# %%
diabetes_dataset.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %%
# Seperating the data and labels   
X = diabetes_dataset.drop(columns = 'Outcome', axis=1)
Y = diabetes_dataset['Outcome']

# %%
print(X)
print(Y)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %% [markdown]
# ## Splitting the Data into Train and Test Data

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, stratify = Y, random_state = 2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (768, 8) (614, 8) (154, 8)

# %% [markdown]
# ## Data Standardization

# %%
scaler = StandardScaler()
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)
print(X)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %% [markdown]
# ## Training the Model

# %%
classifier = svm.SVC(kernel = 'linear')

# %%
# Training the Support Vector Machine Classifier
classifier.fit(X_train, Y_train)
# Out:
# SVC(kernel='linear')

# %% [markdown]
# ## Model Evalution

# %%
# Accuracy Score on Training Data
X_train_prediction = classifier.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print('Accuracy score on the training data : ', training_data_accuracy)
# Out:
# Accuracy score on the training data :  0.7866449511400652

# %%
# Accuracy Score on Testing Data
X_test_prediction = classifier.predict(X_test)
testing_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print('Accuracy score on the testing data : ', testing_data_accuracy)
# Out:
# Accuracy score on the testing data :  0.7727272727272727

# %% [markdown]
# ## Making a Predictive Model

# %%
input_data1 = (0, 80, 65, 25, 50, 24.0, 0.3, 22)    # Non-Diabetic
input_data2 = (4, 145, 76, 28, 170, 36.1, 0.8, 48)    # Diabetic

# Input Data Prediction
def input_data_prediction(input_data):
    
    # Same feature names as used in training
    columns = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 
               'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age']
    # Wrap into a DataFrame
    input_df = pd.DataFrame([input_data], columns=columns)

    # Standardize the input data
    std_data = scaler.transform(input_df)

    # Predicting the outcome of input data
    prediction = classifier.predict(std_data)
    
    return prediction

# Display Result of the Prediction
def result(prediction):   
    if(prediction[0] == 0):
        print('The person is Non-Diabetic.')
    else:
        print('The person is Diabetic.')

prediction1 = input_data_prediction(input_data1)
print(prediction1)
result(prediction1)

prediction2 = input_data_prediction(input_data2)
print(prediction2)
result(prediction2)
# Out:
# [0]
# The person is Non-Diabetic.
# [1]
# The person is Diabetic.
